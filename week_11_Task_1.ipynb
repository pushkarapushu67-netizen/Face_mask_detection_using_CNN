# %% [markdown]
# # **Face Mask Detection using CNN**

# %% [markdown]
# The goal of this project is to develop a deep learning model using Convolutional Neural
# Networks (CNN) that can automatically detect whether a person in an image or video is
# wearing a face mask or not.
#
# This system can be used in real-world scenarios such as:
# *   Public places (airports, malls, hospitals)
# *   Surveillance systems
# *   Entry control systems for safety compliance
#
# The model should take an input image (or video frame) and classify it into:
# * With Mask
# * Without Mask

# %% [markdown]
# **Import & Load Dataset**

# %%
# !pip install kagglehub

import kagglehub

# Download dataset
path = kagglehub.dataset_download("omkargurav/face-mask-dataset")

print("Path to dataset files:", path)
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /usr/local/lib/python3.12/dist-packages (from kagglehub) (0.1.18)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (26.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2026.2.25)
# Using Colab cache for faster access to the 'face-mask-dataset' dataset.
# Path to dataset files: /kaggle/input/face-mask-dataset

# %% [markdown]
# **Image Data Generator**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_height = 224
img_width = 224
batch_size = 32

data_gen = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.15
)

# %% [markdown]
# **Load Data**

# %%
train_gen = data_gen.flow_from_directory(
    path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

val_gen = data_gen.flow_from_directory(
    path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 6421 images belonging to 1 classes.
# Found 1132 images belonging to 1 classes.

# %% [markdown]
# **Build CNN Model**

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

model = models.Sequential([
    layers.Input(shape=(224,224,3)),

    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),

    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=Adam(),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     5,537,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,631,169 (21.48 MB)
#  Trainable params: 5,631,169 (21.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Train Model**

# %%
history = model.fit(
    train_gen,
    epochs=10,
    validation_data=val_gen
)
# Out:
# Epoch 1/10
# 128/201 ━━━━━━━━━━━━━━━━━━━━ 3:44 3s/step - accuracy: 0.9960 - loss: 0.0283
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 662s 3s/step - accuracy: 0.9995 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 666s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 664s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 656s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 654s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 657s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 659s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 8/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 657s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 657s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 671s 3s/step - accuracy: 1.0000 - loss: 8.3127e-37 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %% [markdown]
# **Evaluate Model**

# %%
loss, acc = model.evaluate(val_gen)

print("Validation Accuracy:", acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4002/1844032077.py in <cell line: 0>()
# ----> 1 loss, acc = model.evaluate(val_gen)
#       2
#       3 print("Validation Accuracy:", acc)
#
# NameError: name 'model' is not defined
